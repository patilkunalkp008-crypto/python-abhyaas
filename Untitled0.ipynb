# %%
print("Hello Shalini")

# %%
print("Shalini")

# %%
print("Python")

# %%
print("Age")

# %%
name="Shalini"
age=20

print(name)
print(age)

# %%
name=input("kunal :" )
print("Hello",name)

# %%
name=input("Enter your name: ")
age=input("Enter your age")

print("My name is",name)
print("My age is",age)

# %%
name=input("Raju :")
city = input("Mumbai: ")

print("My name is", Raju)
print("I live in", Nashik)

# %%
action:", a - b)
print("Multiplication:", a*b)

# %%
age = int(input("21: "))
print("Your age is", age)

# %%
age = int(input("Enter your age : "))

if age >= 18:
     print("you are Adult")
else:
     print("you are Minor")

# %%
for i in range(1, 6):
    print("Hello")

# %%
for i in range(5):
    print(i)

# %%
i = 1

while i <= 5:
    print(i)
    i = i + 1

# %%
for i in range(1, 11):
    print(i)

# %%
for i in range(1, 11):
    if i % 2 == 0:
        print(i)

# %%
//
+--------------------------------------------
-----------------+
//|           claude Turbo Scalper v7
SNIPER EDITION
//
+---------------------------------------------
---------------------+
#poperty strict
#include

# %%
print("Shalini")
Print("age")

name="Shalini"
age=20

print(Name)
print(age)

# %%
name = ("Enter your name ")
age =  ("Enter your age ")


print ("My name is shalini")
print ("My age is 21")

# %%
for i in range (5):
    print(i)

# %%
for i range (1,6):
    print("Hello")

# %%
for i in range (1,11):
    print(i)

# %%
i=1

while i <= 5:
    print(i)
    i=i+1

# %%
for i in range (1,11):
    if i % 2 == 0:
        print(i)

# %%
num= int(input ("Enter number: "))

for i in range (1,11):
    print(num,  "x", i, "=", num * i)

# %%
name= input("Enter ypur name: ")
marks = int(input("Enter your marks:"))

if marks >= 50:
    print(name, "is passed")
else:
    print(name,"is Failed")

# %%
for i in range (1,6):
    print("*" * i)

# %%
num = int(input(" 2: "))

# %%
num = int(input("Enter number : "))

if num % 2 ==0:
    print("Even")
else:
    print("Odd")

# %%
for i in range(5, 0, -1):
    print("*" * i)

# %%
total = 0

for i in range (1,11):
    total = total + i

print(total)

# %%
def greet():
    print("Hello Shalini")

greet(Shalini)

# %%
def add(a, b):
    return a + b

result = add(5,3)
print(result)

# %%
numbers = [1, 2, 3, 4, 5]
print(numbers)

# %%
marks = [50, 70, 90, 30]

for m in marks:
    if m >= 50:
        print(m, "Pass")
    else:
        print(m, "Fail")
marks = [45, 60, 80]
check_pass(marks)

# %%
def check_pass(marks):
    for m in marks:
        if m >= 50:
            print(m,"Pass")
        else:
            print(m,"Fail")

marks = [45, 60, 80]
check_pass(marks)

# %%
name = "Shalini"
print(name)

# %%
name ="Shalini"

print(name.upper())   # SHALINI
print(name.lower())   # shalini
print(len(name))      # length

# %%
name = "Python"

print(name[0])    # P
print(name[3])    # h

# %%
text = "Python"

print(text[0:3])   # Pyt
print(text[2:6])   # thon

# %%
numbers = [1, 2, 3]
numbers.append(4)

print(numbers)

# %%
numbers.remove(2)
print(numbers)
print(len(numbers))

# %%
marks = [45, 67, 89, 30]

for m in marks:
    print(m)

# %%
marks = [45, 67, 89, 30]

highest = marks[0]

for m in marks:
    if m > highest:
        highest = m

print("Highest marks is:", highest)

# %%
marks = [50, 60, 70, 80]

total = 0

for m in marks:
    total = total + m

avg = total / len(marks)

print("Average:", avg)

# %%
student = {
    "name": "sahalini",
    "age": 20,
    "marks": 85
}

print(students)

# %%
print(student["name"])
print(student["age"])

# %%
student["city"] ="Nashik"  # add
student["marks"] = 90      # update

print(student)

# %%
for key, value in student.items():
    print(key, ":", value)

# %%
student = {}

student["name"] = input("Enter name: ")
student["age"] = input("Enter age: ")
student["marks"] = int(input("Enter marks:"))

print("\nStudent Details:")
for key, value in student.items():
    print(key, ":", value)

# %%
student = {
    "name": "Shalini",
    "marks": 45
}

if student["marks"]>=50:
    print(student["name"], "Pass")
else:
    print(student["name"], "Fail")

# %%
student = [
    {"name": "A", "marks": 60},
    {"name": "B", "marks": 70},
    {"name": "C", "marks": 80},
]

for s in students:
    if s["marks"] >=50:
        print(s["name"], "pass")
    else:
        print(s["name"], "Fail")

# %%
file = open("data.txt", "w")

file.write("Hello Shalini\n")
file.write("Python Learning\n")

file.close()

# %%
file = open("data.txt", "r")

data = file.read()
print(data)

file.close()

# %%
file = open("data.txt", "a")

file.write("New Line Added\n")

file.close()

# %%
file = open("student.txt", "a")

name = input("Enter name: ")
marks = input("Enter marks: ")

file.write(name + "_" + marks + "\n")

file.close()

print("Data saved successfully!")

# %%
file = open("student.txt", "a")

name = input("Shalini:")
marks = input("78:")

file.write(name + "_" + marks + "\n")

file.close()

print("Data saved successfully")

# %%
for i in range(3):
    name = input("Enter name:")
    marks = int(input("Enter marks:"))
    students.append({"name": name, "marks": marks})

with open("student.txt", "a") as file:
    for s in students:
        if s["marks"] >=50:
            status = "Pass"
        else:
            status ="Fail"

        print(s["name"], "_", s["marks"].)
        file.write(s["name"] + "_" + str(s["marks"]) + "\n")

# %%
for i in range(3):
    name = input("Enter name:")
    age = int(input("Enter age:"))
    students.append({"name" : name, "marks" : marks})
